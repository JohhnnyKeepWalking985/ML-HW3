# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from kmeans import KMeansClustering
from em import EMClustering
import warnings
warnings.filterwarnings("ignore")

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # PCA + kmeans

# %%
dataset_path = "../datasets/dr/mkt/pca_train.csv"
mkt_pca_train = pd.read_csv(dataset_path)

# %%
inertia = []
silhouette_scores = []
K_range = range(2, 11)

for k in K_range:
    model = KMeansClustering(n_clusters=k)
    labels = model.fit(mkt_pca_train)
    inertia.append(model.inertia_)
    silhouette_scores.append(model.silhouette_score())

plt.figure(figsize=(8, 4))
plt.plot(K_range, inertia, marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Inertia")
plt.title("Elbow Method for Optimal k")
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(K_range, silhouette_scores, marker='o', color='r')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score for Optimal k")
plt.show()

best_k = K_range[np.argmax(silhouette_scores)]
print(f"Best k selected: {best_k}")
# Out:
# Best k selected: 2

# %%
best_k = 2
kmeans = KMeansClustering(n_clusters=best_k, save_data=True)
labels = kmeans.fit(mkt_pca_train)

kmeans.save_results(filename="../datasets/dr_cluster/mkt/pca_kmeans_train.csv")
kmeans.save_model(filename="../model_checkpoints/mkt/pca_kmeans_model.pkl")

kmeans.plot_clusters()

dataset_path = "../datasets/dr/mkt/pca_test.csv"
mkt_pca_test = pd.read_csv(dataset_path)
KMeansClustering.inference("../model_checkpoints/mkt/pca_kmeans_model.pkl", mkt_pca_test, output_file="../datasets/dr_cluster/mkt/pca_kmeans_test.csv")
# Out:
# Results saved to ../datasets/dr_cluster/mkt/pca_kmeans_train.csv
# Model saved to ../model_checkpoints/mkt/pca_kmeans_model.pkl
# Loading model from ../model_checkpoints/mkt/pca_kmeans_model.pkl...
# Model loaded successfully!
# Inference results saved to ../datasets/dr_cluster/mkt/pca_kmeans_test.csv

# %% [markdown]
# # ICA + Kmeans

# %%
dataset_path = "../datasets/dr/mkt/ica_train.csv"
mkt_ica_train = pd.read_csv(dataset_path)

inertia = []
silhouette_scores = []
K_range = range(2, 11)

for k in K_range:
    model = KMeansClustering(n_clusters=k)
    labels = model.fit(mkt_ica_train)
    inertia.append(model.inertia_)
    silhouette_scores.append(model.silhouette_score())

plt.figure(figsize=(8, 4))
plt.plot(K_range, inertia, marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Inertia")
plt.title("Elbow Method for Optimal k")
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(K_range, silhouette_scores, marker='o', color='r')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score for Optimal k")
plt.show()

best_k = K_range[np.argmax(silhouette_scores)]
print(f"Best k selected: {best_k}")
# Out:
# Best k selected: 4

# %%
dataset_path = "../datasets/dr/mkt/ica_train.csv"
mkt_ica_train = pd.read_csv(dataset_path)

best_k = 4
kmeans = KMeansClustering(n_clusters=best_k, save_data=True)
labels = kmeans.fit(mkt_ica_train)

kmeans.save_results(filename="../datasets/dr_cluster/mkt/ica_kmeans_train.csv")
kmeans.save_model(filename="../model_checkpoints/mkt/ica_kmeans_model.pkl")

kmeans.plot_clusters()

dataset_path = "../datasets/dr/mkt/ica_test.csv"
mkt_ica_test = pd.read_csv(dataset_path)
KMeansClustering.inference("../model_checkpoints/mkt/ica_kmeans_model.pkl", mkt_ica_test, output_file="../datasets/dr_cluster/mkt/ica_kmeans_test.csv")
# Out:
# Results saved to ../datasets/dr_cluster/mkt/ica_kmeans_train.csv
# Model saved to ../model_checkpoints/mkt/ica_kmeans_model.pkl
# Loading model from ../model_checkpoints/mkt/ica_kmeans_model.pkl...
# Model loaded successfully!
# Inference results saved to ../datasets/dr_cluster/mkt/ica_kmeans_test.csv

# %% [markdown]
# # RP + Kmeans

# %%
dataset_path = "../datasets/dr/mkt/rp_train.csv"
mkt_rp_train = pd.read_csv(dataset_path)

inertia = []
silhouette_scores = []
K_range = range(2, 11)

for k in K_range:
    model = KMeansClustering(n_clusters=k)
    labels = model.fit(mkt_rp_train)
    inertia.append(model.inertia_)
    silhouette_scores.append(model.silhouette_score())

plt.figure(figsize=(8, 4))
plt.plot(K_range, inertia, marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Inertia")
plt.title("Elbow Method for Optimal k")
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(K_range, silhouette_scores, marker='o', color='r')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score for Optimal k")
plt.show()

best_k = K_range[np.argmax(silhouette_scores)]
print(f"Best k selected: {best_k}")
# Out:
# Best k selected: 4

# %%
dataset_path = "../datasets/dr/mkt/rp_train.csv"
mkt_rp_train = pd.read_csv(dataset_path)

best_k = 2
kmeans = KMeansClustering(n_clusters=best_k, save_data=True)
labels = kmeans.fit(mkt_rp_train)

kmeans.save_results(filename="../datasets/dr_cluster/mkt/rp_kmeans_train.csv")
kmeans.save_model(filename="../model_checkpoints/mkt/rp_kmeans_model.pkl")

kmeans.plot_clusters()

dataset_path = "../datasets/dr/mkt/rp_test.csv"
mkt_rp_test = pd.read_csv(dataset_path)
KMeansClustering.inference("../model_checkpoints/mkt/rp_kmeans_model.pkl", mkt_rp_test, output_file="../datasets/dr_cluster/mkt/rp_kmeans_test.csv")
# Out:
# Results saved to ../datasets/dr_cluster/mkt/rp_kmeans_train.csv
# Model saved to ../model_checkpoints/mkt/rp_kmeans_model.pkl
# Loading model from ../model_checkpoints/mkt/rp_kmeans_model.pkl...
# Model loaded successfully!
# Inference results saved to ../datasets/dr_cluster/mkt/rp_kmeans_test.csv

# %% [markdown]
# # Umap + Kmeans

# %%
dataset_path = "../datasets/dr/mkt/umap_train.csv"
mkt_umap_train = pd.read_csv(dataset_path)

inertia = []
silhouette_scores = []
K_range = range(2, 11)

for k in K_range:
    model = KMeansClustering(n_clusters=k)
    labels = model.fit(mkt_umap_train)
    inertia.append(model.inertia_)
    silhouette_scores.append(model.silhouette_score())

plt.figure(figsize=(8, 4))
plt.plot(K_range, inertia, marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Inertia")
plt.title("Elbow Method for Optimal k")
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(K_range, silhouette_scores, marker='o', color='r')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score for Optimal k")
plt.show()

best_k = K_range[np.argmax(silhouette_scores)]
print(f"Best k selected: {best_k}")
# Out:
# Best k selected: 6

# %%
dataset_path = "../datasets/dr/mkt/umap_train.csv"
mkt_umap_train = pd.read_csv(dataset_path)

best_k = 6
kmeans = KMeansClustering(n_clusters=best_k, save_data=True)
labels = kmeans.fit(mkt_umap_train)

kmeans.save_results(filename="../datasets/dr_cluster/mkt/umap_kmeans_train.csv")
kmeans.save_model(filename="../model_checkpoints/mkt/umap_kmeans_model.pkl")

kmeans.plot_clusters()

dataset_path = "../datasets/dr/mkt/umap_test.csv"
mkt_umap_test = pd.read_csv(dataset_path)
KMeansClustering.inference("../model_checkpoints/mkt/umap_kmeans_model.pkl", mkt_umap_test, output_file="../datasets/dr_cluster/mkt/umap_kmeans_test.csv")
# Out:
# Results saved to ../datasets/dr_cluster/mkt/umap_kmeans_train.csv
# Model saved to ../model_checkpoints/mkt/umap_kmeans_model.pkl
# Loading model from ../model_checkpoints/mkt/umap_kmeans_model.pkl...
# Model loaded successfully!
# Inference results saved to ../datasets/dr_cluster/mkt/umap_kmeans_test.csv

# %% [markdown]
# # PCA + EM

# %%
dataset_path = "../datasets/dr/mkt/pca_train.csv"
mkt_pca_train = pd.read_csv(dataset_path)

negative_log_likelihood_score = []
silhouette_scores = []
K_range = range(2, 11)

for k in K_range:
    model = EMClustering(n_components=k)
    labels = model.fit(mkt_pca_train)
    negative_log_likelihood_score.append(model.score)
    silhouette_scores.append(model.silhouette_score())

plt.figure(figsize=(8, 4))
plt.plot(K_range, negative_log_likelihood_score, marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Negative Log Likelihood")
plt.title("Elbow Method for Optimal k")
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(K_range, silhouette_scores, marker='o', color='r')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score for Optimal k")
plt.show()

best_k = K_range[np.argmax(silhouette_scores)]
print(f"Best k selected: {best_k}")
# Out:
# Best k selected: 2

# %%
dataset_path = "../datasets/dr/mkt/pca_train.csv"
mkt_pca_train = pd.read_csv(dataset_path)

best_k = 2
em = EMClustering(n_components=best_k, save_data=True)
labels = em.fit(mkt_pca_train)

em.save_results(filename="../datasets/dr_cluster/mkt/pca_em_train.csv")
em.save_model(filename="../model_checkpoints/mkt/pca_em_model.pkl")

em.plot_clusters()

dataset_path = "../datasets/dr/mkt/pca_test.csv"
mkt_pca_test = pd.read_csv(dataset_path)
em.inference("../model_checkpoints/mkt/pca_em_model.pkl", mkt_pca_test, output_file="../datasets/dr_cluster/mkt/pca_em_test.csv")
# Out:
# Results saved to ../datasets/dr_cluster/mkt/pca_em_train.csv
# Model saved to ../model_checkpoints/mkt/pca_em_model.pkl
# Loading model from ../model_checkpoints/mkt/pca_em_model.pkl...
# Model loaded successfully!
# Inference results saved to ../datasets/dr_cluster/mkt/pca_em_test.csv

# %% [markdown]
# # ICA + EM

# %%
dataset_path = "../datasets/dr/mkt/ica_train.csv"
mkt_ica_train = pd.read_csv(dataset_path)

negative_log_likelihood_score = []
silhouette_scores = []
K_range = range(2, 11)

for k in K_range:
    model = EMClustering(n_components=k)
    labels = model.fit(mkt_ica_train)
    negative_log_likelihood_score.append(model.score)
    silhouette_scores.append(model.silhouette_score())

plt.figure(figsize=(8, 4))
plt.plot(K_range, negative_log_likelihood_score, marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Negative Log Likelihood")
plt.title("Elbow Method for Optimal k")
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(K_range, silhouette_scores, marker='o', color='r')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score for Optimal k")
plt.show()

best_k = K_range[np.argmax(silhouette_scores)]
print(f"Best k selected: {best_k}")
# Out:
# Best k selected: 4

# %%
dataset_path = "../datasets/dr/mkt/ica_train.csv"
mkt_ica_train = pd.read_csv(dataset_path)

best_k = 4
em = EMClustering(n_components=best_k, save_data=True)
labels = em.fit(mkt_ica_train)

em.save_results(filename="../datasets/dr_cluster/mkt/ica_em_train.csv")
em.save_model(filename="../model_checkpoints/mkt/ica_em_model.pkl")

em.plot_clusters()

dataset_path = "../datasets/dr/mkt/ica_test.csv"
mkt_ica_test = pd.read_csv(dataset_path)
em.inference("../model_checkpoints/mkt/ica_em_model.pkl", mkt_ica_test, output_file="../datasets/dr_cluster/mkt/ica_em_test.csv")
# Out:
# Results saved to ../datasets/dr_cluster/mkt/ica_em_train.csv
# Model saved to ../model_checkpoints/mkt/ica_em_model.pkl
# Loading model from ../model_checkpoints/mkt/ica_em_model.pkl...
# Model loaded successfully!
# Inference results saved to ../datasets/dr_cluster/mkt/ica_em_test.csv

# %% [markdown]
# # RP + EM

# %%
dataset_path = "../datasets/dr/mkt/rp_train.csv"
mkt_rp_train = pd.read_csv(dataset_path)

negative_log_likelihood_score = []
silhouette_scores = []
K_range = range(2, 11)

for k in K_range:
    model = EMClustering(n_components=k)
    labels = model.fit(mkt_rp_train)
    negative_log_likelihood_score.append(model.score)
    silhouette_scores.append(model.silhouette_score())

plt.figure(figsize=(8, 4))
plt.plot(K_range, negative_log_likelihood_score, marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Negative Log Likelihood")
plt.title("Elbow Method for Optimal k")
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(K_range, silhouette_scores, marker='o', color='r')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score for Optimal k")
plt.show()

best_k = K_range[np.argmax(silhouette_scores)]
print(f"Best k selected: {best_k}")
# Out:
# Best k selected: 2

# %%
dataset_path = "../datasets/dr/mkt/rp_train.csv"
mkt_rp_train = pd.read_csv(dataset_path)

best_k = 2
em = EMClustering(n_components=best_k, save_data=True)
labels = em.fit(mkt_rp_train)

em.save_results(filename="../datasets/dr_cluster/mkt/rp_em_train.csv")
em.save_model(filename="../model_checkpoints/mkt/rp_em_model.pkl")

em.plot_clusters()

dataset_path = "../datasets/dr/mkt/rp_test.csv"
mkt_rp_test = pd.read_csv(dataset_path)
em.inference("../model_checkpoints/mkt/rp_em_model.pkl", mkt_rp_test, output_file="../datasets/dr_cluster/mkt/rp_em_test.csv")
# Out:
# Results saved to ../datasets/dr_cluster/mkt/rp_em_train.csv
# Model saved to ../model_checkpoints/mkt/rp_em_model.pkl
# Loading model from ../model_checkpoints/mkt/rp_em_model.pkl...
# Model loaded successfully!
# Inference results saved to ../datasets/dr_cluster/mkt/rp_em_test.csv

# %% [markdown]
# # Umap + EM

# %%
dataset_path = "../datasets/dr/mkt/umap_train.csv"
mkt_umap_train = pd.read_csv(dataset_path)

negative_log_likelihood_score = []
silhouette_scores = []
K_range = range(2, 11)

for k in K_range:
    model = EMClustering(n_components=k)
    labels = model.fit(mkt_umap_train)
    negative_log_likelihood_score.append(model.score)
    silhouette_scores.append(model.silhouette_score())

plt.figure(figsize=(8, 4))
plt.plot(K_range, negative_log_likelihood_score, marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Negative Log Likelihood")
plt.title("Elbow Method for Optimal k")
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(K_range, silhouette_scores, marker='o', color='r')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score for Optimal k")
plt.show()

best_k = K_range[np.argmax(silhouette_scores)]
print(f"Best k selected: {best_k}")
# Out:
# Best k selected: 6

# %%
dataset_path = "../datasets/dr/mkt/umap_train.csv"
mkt_umap_train = pd.read_csv(dataset_path)

best_k = 6
em = EMClustering(n_components=best_k, save_data=True)
labels = em.fit(mkt_umap_train)

em.save_results(filename="../datasets/dr_cluster/mkt/umap_em_train.csv")
em.save_model(filename="../model_checkpoints/mkt/umap_em_model.pkl")

em.plot_clusters()

dataset_path = "../datasets/dr/mkt/umap_test.csv"
mkt_umap_test = pd.read_csv(dataset_path)
em.inference("../model_checkpoints/mkt/umap_em_model.pkl", mkt_umap_test, output_file="../datasets/dr_cluster/mkt/umap_em_test.csv")
# Out:
# Results saved to ../datasets/dr_cluster/mkt/umap_em_train.csv
# Model saved to ../model_checkpoints/mkt/umap_em_model.pkl
# Loading model from ../model_checkpoints/mkt/umap_em_model.pkl...
# Model loaded successfully!
# Inference results saved to ../datasets/dr_cluster/mkt/umap_em_test.csv
