# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from kmeans import KMeansClustering
from em import EMClustering
import warnings
warnings.filterwarnings("ignore")

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # PCA + kmeans

# %%
dataset_path = "../datasets/dr/spotify/pca_train.csv"
spotify_pca_train = pd.read_csv(dataset_path)

inertia = []
silhouette_scores = []
K_range = range(2, 11)

for k in K_range:
    model = KMeansClustering(n_clusters=k)
    labels = model.fit(spotify_pca_train)
    inertia.append(model.inertia_)
    silhouette_scores.append(model.silhouette_score())

plt.figure(figsize=(8, 4))
plt.plot(K_range, inertia, marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Inertia")
plt.title("Elbow Method for Optimal k")
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(K_range, silhouette_scores, marker='o', color='r')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score for Optimal k")
plt.show()

best_k = K_range[np.argmax(silhouette_scores)]
print(f"Best k selected: {best_k}")
# Out:
# Best k selected: 2

# %%
best_k = 2
kmeans = KMeansClustering(n_clusters=best_k, save_data=True)
labels = kmeans.fit(spotify_pca_train)

kmeans.plot_clusters()

# %% [markdown]
# # ICA + Kmeans

# %%
dataset_path = "../datasets/dr/spotify/ica_train.csv"
spotify_ica_train = pd.read_csv(dataset_path)

inertia = []
silhouette_scores = []
K_range = range(2, 11)

for k in K_range:
    model = KMeansClustering(n_clusters=k)
    labels = model.fit(spotify_ica_train)
    inertia.append(model.inertia_)
    silhouette_scores.append(model.silhouette_score())

plt.figure(figsize=(8, 4))
plt.plot(K_range, inertia, marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Inertia")
plt.title("Elbow Method for Optimal k")
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(K_range, silhouette_scores, marker='o', color='r')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score for Optimal k")
plt.show()

best_k = K_range[np.argmax(silhouette_scores)]
print(f"Best k selected: {best_k}")
# Out:
# Best k selected: 7

# %%
dataset_path = "../datasets/dr/spotify/ica_train.csv"
spotify_ica_train = pd.read_csv(dataset_path)

best_k = 7
kmeans = KMeansClustering(n_clusters=best_k, save_data=True)
labels = kmeans.fit(spotify_ica_train)

kmeans.plot_clusters()

# %% [markdown]
# # RP + Kmeans

# %%
dataset_path = "../datasets/dr/spotify/rp_train.csv"
spotify_rp_train = pd.read_csv(dataset_path)

inertia = []
silhouette_scores = []
K_range = range(2, 11)

for k in K_range:
    model = KMeansClustering(n_clusters=k)
    labels = model.fit(spotify_rp_train)
    inertia.append(model.inertia_)
    silhouette_scores.append(model.silhouette_score())

plt.figure(figsize=(8, 4))
plt.plot(K_range, inertia, marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Inertia")
plt.title("Elbow Method for Optimal k")
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(K_range, silhouette_scores, marker='o', color='r')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score for Optimal k")
plt.show()

best_k = K_range[np.argmax(silhouette_scores)]
print(f"Best k selected: {best_k}")
# Out:
# Best k selected: 2

# %%
dataset_path = "../datasets/dr/spotify/rp_train.csv"
spotify_rp_train = pd.read_csv(dataset_path)

best_k = 2
kmeans = KMeansClustering(n_clusters=best_k, save_data=True)
labels = kmeans.fit(spotify_rp_train)

kmeans.plot_clusters()

# %% [markdown]
# # Umap + Kmeans

# %%
dataset_path = "../datasets/dr/spotify/umap_train.csv"
spotify_umap_train = pd.read_csv(dataset_path)

inertia = []
silhouette_scores = []
K_range = range(2, 11)

for k in K_range:
    model = KMeansClustering(n_clusters=k)
    labels = model.fit(spotify_umap_train)
    inertia.append(model.inertia_)
    silhouette_scores.append(model.silhouette_score())

plt.figure(figsize=(8, 4))
plt.plot(K_range, inertia, marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Inertia")
plt.title("Elbow Method for Optimal k")
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(K_range, silhouette_scores, marker='o', color='r')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score for Optimal k")
plt.show()

best_k = K_range[np.argmax(silhouette_scores)]
print(f"Best k selected: {best_k}")
# Out:
# Best k selected: 3

# %%
dataset_path = "../datasets/dr/spotify/umap_train.csv"
spotify_umap_train = pd.read_csv(dataset_path)

best_k = 3
kmeans = KMeansClustering(n_clusters=best_k, save_data=True)
labels = kmeans.fit(spotify_umap_train)

kmeans.plot_clusters()

# %% [markdown]
# # PCA + EM

# %%
dataset_path = "../datasets/dr/spotify/pca_train.csv"
spotify_pca_train = pd.read_csv(dataset_path)

negative_log_likelihood_score = []
silhouette_scores = []
K_range = range(2, 11)

for k in K_range:
    model = EMClustering(n_components=k)
    labels = model.fit(spotify_pca_train)
    negative_log_likelihood_score.append(model.score)
    silhouette_scores.append(model.silhouette_score())

plt.figure(figsize=(8, 4))
plt.plot(K_range, negative_log_likelihood_score, marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Negative Log Likelihood")
plt.title("Elbow Method for Optimal k")
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(K_range, silhouette_scores, marker='o', color='r')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score for Optimal k")
plt.show()

best_k = K_range[np.argmax(silhouette_scores)]
print(f"Best k selected: {best_k}")
# Out:
# Best k selected: 2

# %%
dataset_path = "../datasets/dr/spotify/pca_train.csv"
spotify_pca_train = pd.read_csv(dataset_path)

best_k = 2
em = EMClustering(n_components=best_k, save_data=True)
labels = em.fit(spotify_pca_train)

em.plot_clusters()

# %% [markdown]
# # ICA + EM

# %%
dataset_path = "../datasets/dr/spotify/ica_train.csv"
spotify_ica_train = pd.read_csv(dataset_path)

negative_log_likelihood_score = []
silhouette_scores = []
K_range = range(2, 11)

for k in K_range:
    model = EMClustering(n_components=k)
    labels = model.fit(spotify_ica_train)
    negative_log_likelihood_score.append(model.score)
    silhouette_scores.append(model.silhouette_score())

plt.figure(figsize=(8, 4))
plt.plot(K_range, negative_log_likelihood_score, marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Negative Log Likelihood")
plt.title("Elbow Method for Optimal k")
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(K_range, silhouette_scores, marker='o', color='r')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score for Optimal k")
plt.show()

best_k = K_range[np.argmax(silhouette_scores)]
print(f"Best k selected: {best_k}")
# Out:
# Best k selected: 2

# %%
dataset_path = "../datasets/dr/spotify/ica_train.csv"
spotify_ica_train = pd.read_csv(dataset_path)

best_k = 2
em = EMClustering(n_components=best_k, save_data=True)
labels = em.fit(spotify_ica_train)

em.plot_clusters()

# %% [markdown]
# # RP + EM

# %%
dataset_path = "../datasets/dr/spotify/rp_train.csv"
spotify_rp_train = pd.read_csv(dataset_path)

negative_log_likelihood_score = []
silhouette_scores = []
K_range = range(2, 11)

for k in K_range:
    model = EMClustering(n_components=k)
    labels = model.fit(spotify_rp_train)
    negative_log_likelihood_score.append(model.score)
    silhouette_scores.append(model.silhouette_score())

plt.figure(figsize=(8, 4))
plt.plot(K_range, negative_log_likelihood_score, marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Negative Log Likelihood")
plt.title("Elbow Method for Optimal k")
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(K_range, silhouette_scores, marker='o', color='r')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score for Optimal k")
plt.show()

best_k = K_range[np.argmax(silhouette_scores)]
print(f"Best k selected: {best_k}")
# Out:
# Best k selected: 2

# %%
dataset_path = "../datasets/dr/spotify/rp_train.csv"
spotify_rp_train = pd.read_csv(dataset_path)

best_k = 2
em = EMClustering(n_components=best_k, save_data=True)
labels = em.fit(spotify_rp_train)

em.plot_clusters()

# %% [markdown]
# # Umap + EM

# %%
dataset_path = "../datasets/dr/spotify/umap_train.csv"
spotify_umap_train = pd.read_csv(dataset_path)

negative_log_likelihood_score = []
silhouette_scores = []
K_range = range(2, 11)

for k in K_range:
    model = EMClustering(n_components=k)
    labels = model.fit(spotify_umap_train)
    negative_log_likelihood_score.append(model.score)
    silhouette_scores.append(model.silhouette_score())

plt.figure(figsize=(8, 4))
plt.plot(K_range, negative_log_likelihood_score, marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Negative Log Likelihood")
plt.title("Elbow Method for Optimal k")
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(K_range, silhouette_scores, marker='o', color='r')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score for Optimal k")
plt.show()

best_k = K_range[np.argmax(silhouette_scores)]
print(f"Best k selected: {best_k}")
# Out:
# Best k selected: 3

# %%
dataset_path = "../datasets/dr/spotify/umap_train.csv"
spotify_umap_train = pd.read_csv(dataset_path)

best_k = 3
em = EMClustering(n_components=best_k, save_data=True)
labels = em.fit(spotify_umap_train)

em.plot_clusters()
